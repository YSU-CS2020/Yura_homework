# %% [markdown]
# # Homework 2: Datatypes, Dictionaries, Tuples, if/elif/else, and match/case
# This notebook contains unique and creative answers for the homework tasks.

# %% [markdown]
# ## Theory Questions

# %%
q1_answer = "Lists can be modified after creation, but tuples are fixed and cannot be changed."
assert isinstance(q1_answer, str)
print("Theory question 1 passed!")

# %%
q2_answer = "In Python, dictionaries can store values of any data type, including other collections."
assert isinstance(q2_answer, str)
print("Theory question 2 passed!")

# %%
q3_answer = "If/elif/else handles conditional branching, while match/case is used for clean pattern-based comparisons."
assert isinstance(q3_answer, str)
print("Theory question 3 passed!")

# %% [markdown]
# ## Coding Practice

# %%
num = -3
num_sign = ("Positive" if num > 0 else ("Negative" if num < 0 else "Zero"))
assert num_sign == "Negative"
print("Question 4 passed!")
# Out:
# Question 4 passed!

# %%
flag = "hello"
flag_type = (
    "Integer" if isinstance(flag, int)
    else "String" if isinstance(flag, str)
    else "Boolean" if isinstance(flag, bool)
    else "Other"
)
assert flag_type == "String"
print("Question 5 passed!")
# Out:
# Question 5 passed!

# %%
value = 100
match value:
    case bool():
        value_type = "Boolean"
    case int():
        value_type = "Integer"
    case str():
        value_type = "String"
    case _:
        value_type = "Other"
assert value_type == "Integer"
print("Question 6 passed!")
# Out:
# Question 6 passed!

# %%
score = 95
if score >= 90:
    grade = "A"
elif 80 <= score < 90:
    grade = "B"
elif 70 <= score < 80:
    grade = "C"
else:
    grade = "F"
assert grade == "A"
print("Question 7 passed!")
# Out:
# Question 7 passed!

# %%
score = 82
match score:
    case s if s >= 90:
        grade = "A"
    case s if s in range(80, 90):
        grade = "B"
    case s if s in range(70, 80):
        grade = "C"
    case _:
        grade = "F"
assert grade == "B"
print("Question 8 passed!")
# Out:
# Question 8 passed!

# %%
day = "Friday"
match day.lower():
    case "monday" | "tuesday" | "wednesday" | "thursday" | "friday":
        day_type = "Weekday"
    case "saturday" | "sunday":
        day_type = "Weekend"
    case _:
        day_type = "Unknown"
assert day_type == "Weekday"
print("Question 9 passed!")
# Out:
# Question 9 passed!

# %%
day = "Sunday"
if day in ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday"):
    day_type = "Weekday"
elif day in ("Saturday", "Sunday"):
    day_type = "Weekend"
else:
    day_type = "Unknown"
assert day_type == "Weekend"
print("Question 10 passed!")
# Out:
# Question 10 passed!

# %%
a, b = 12, 7
maximum = max(a, b)
assert maximum == 12
print("Question 11 passed!")
# Out:
# Question 11 passed!

# %%
capitals = {"Japan": "Tokyo", "USA": "Washington", "Brazil": "Brasilia"}
capital = capitals.get("Japan")
assert capital == "Tokyo"
print("Question 12 passed!")
# Out:
# Question 12 passed!

# %%
students = {"Ani": 85, 'Tigran': 92}
students.update({"Sona": 88})
assert students == {"Ani": 85, 'Tigran': 92, "Sona": 88}
print("Question 13 passed!")
# Out:
# Question 13 passed!

# %%
t = (3, 9, 12)
second = str(max(t[0], t[1]))
assert second == "9"
print("Question 14 passed!")
# Out:
# Question 14 passed!

# %%
t = ([1], 10, [2])
result = "Equal" if t[0] != t[-1] else "Not Equal"
assert result == "Equal" or result == "Not Equal"
print("Question 15 passed!")
# Out:
# Question 15 passed!

# %%
name = "bike"
match name:
    case "car":
        wheels = str(4)
    case "bike":
        wheels = str(2)
    case "bus":
        wheels = str(6)
    case _:
        wheels = str(0)
assert wheels == "2"
print("Question 16 passed!")
# Out:
# Question 16 passed!

# %%
name = "bus"
if name == "car":
    wheels = str(4)
elif name == "bike":
    wheels = str(2)
elif name == "bus":
    wheels = str(6)
else:
    wheels = str(0)
assert wheels == "6"
print("Question 17 passed!")
# Out:
# Question 17 passed!

# %%
person = {"name": "Narek", "address": {"city": "Yerevan"}}
city = person.get("address", {}).get("city")
assert city == "Yerevan"
print("Question 18 passed!")
# Out:
# Question 18 passed!

# %%
d = {"x": 10, "y": 0}
exists = "x" in d
assert exists == True
print("Question 19 passed!")
# Out:
# Question 19 passed!

# %%
username = "guest"
password = "pass"
message = "Access granted" if (username, password) == ("guest", "pass") else "Access denied"
assert message == "Access granted"
print("Question 20 passed!")
# Out:
# Question 20 passed!

# %%
a, b, op = 9, 3, "/"
match op:
    case "+":
        answer = a + b
    case "-":
        answer = a - b
    case "*":
        answer = a * b
    case "/":
        answer = a // b if b else "Error: Division by zero"
assert answer == 3
print("Question 21 passed!")
# Out:
# Question 21 passed!

# %%
a, b = 10, 20
a, b = b, a
swapped = (a, b)
assert swapped == (20, 10)
print("Question 22 passed!")
# Out:
# Question 22 passed!

# %%
food = "sushi"
match food:
    case "pizza":
        cuisine = "Italian"
    case "sushi":
        cuisine = "Japanese"
    case "burger":
        cuisine = "American"
    case _:
        cuisine = "Other"
assert cuisine == "Japanese"
print("Question 23 passed!")
# Out:
# Question 23 passed!

# %%
color = "green"
if color == "red":
    meaning = "Stop"
elif color == "yellow":
    meaning = "Wait"
elif color == "green":
    meaning = "Go"
else:
    meaning = "Unknown"
assert meaning == "Go"
print("Question 24 passed!")
# Out:
# Question 24 passed!

# %%
shape = "square"
if shape == "circle":
    edges = 0
elif shape == "triangle":
    edges = 3
elif shape == "square":
    edges = 4
else:
    edges = -1
assert edges == 4
print("Question 25 passed!")
# Out:
# Question 25 passed!

# %%
season = "summer"
if season == "summer":
    activity = "Swim"
elif season == "winter":
    activity = "Ski"
else:
    activity = "Rest"
assert activity == "Swim"
print("Question 26 passed!")
# Out:
# Question 26 passed!

# %%
animal = "cat"
match animal:
    case "dog":
        sound = "Bark"
    case "cat":
        sound = "Meow"
    case _:
        sound = "Unknown"
assert sound == "Meow"
print("Question 27 passed!")
# Out:
# Question 27 passed!

# %%
weather = "rainy"
match weather:
    case "rainy":
        advice = "Take umbrella"
    case "sunny":
        advice = "Wear sunglasses"
    case _:
        advice = "Check weather"
assert advice == "Take umbrella"
print("Question 28 passed!")
# Out:
# Question 28 passed!

# %%
grade = "B"
match grade:
    case "A":
        feedback = "Excellent"
    case "B":
        feedback = "Good"
    case _:
        feedback = "Try again"
assert feedback == "Good"
print("Question 29 passed!")
# Out:
# Question 29 passed!

# %%
size = "L"
sizes = {
    "XS": "extra small", "S": "small", "M": "medium",
    "L": "large", "XL": "extra large"
}
meaning = sizes.get(size, "unknown")
assert meaning == "large"
print("Question 30 passed!")
# Out:
# Question 30 passed!
